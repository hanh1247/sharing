# %%
import pandas as pd
temperature=pd.read_csv('temperature.csv')
temperature
# Out:
#          Date  Temperature
# 0  03/03/2019         14.0
# 1  04/03/2019         15.0
# 2  05/03/2019         18.0
# 3  06/03/2019         16.0
# 4  07/03/2019         16.5
# 5  08/03/2019         19.0
# 6  09/03/2019         13.9
# 7  10/03/2019         62.6
# 8  11/03/2019         65.0

# %%
# Tập dữ liệu được thu thập từ các nguồn khác nhay với dữ liệu nhiệt độ C và độ F được hợp nhất với nhay
# Xác định sự hiện diện của độ F một cách trực quan thông qua biểu đồ phân tán dữ liệu

# %%
# Nhớ cài pip install matplotlib
import matplotlib.pyplot as plt
#Creat scatter plot
plt.scatter(x="Date",y='Temperature',data=temperature)
#Creat title, xlabel and ylabel
plt.title('Tempurature in XYZ March 2019')
plt.xlabel('Date')
plt.ylabel('Temperature in XYZ')
#Show plot
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
fig=plt.subplots()
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 fig=plt.subplots()
# ----> 2 fig.autofmt_xdate()
#
# AttributeError: 'tuple' object has no attribute 'autofmt_xdate'

# %%
# C= (F-32) * 5/9
temp_fah=temperature.loc[temperature['Temperature']>40,'Temperature']
temp_fah
# Out:
# 7    62.6
# 8    65.0
# Name: Temperature, dtype: float64

# %%
temp_cels=(temp_fah - 32)* (5/9)
temperature.loc[temperature['Temperature']>40,'Temperature']=temp_cels
